# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
#url='https://www.wantgoo.com/stock?__cf_chl_jschl_tk__=9b90be6ec6886dddd9da0cc71c53b0dd8314515b-1586795396-0-ATUxku2YUsgkqZZ7aDWdoQFTaiytS_bycdoinJxohq84f57VzQ4_eGYdcNac58dHSiLMj0fIuLzOMDwm3rd040SKwxN_MITyiUtup0euRXsvknrbtqXQpFva-owXsMh4PceOtKPoua7OGWd_01XlEt2vARGQVFtxsuIRMRdp55Wn6LYsFsHtqkZ-VNVruJLkyAHdKDVM-rAWiKDzZ85B9QeXlJXvGeDaijIaZ4svTtXqLCJ7GaiyU4HGeyEaeATZFobATf9LMAbhrZgfnw5VV8WIv1yB2vX2QvVdyYgj0BiHPKJxbfIgn5vy3noWjdTABYNxWD5nUnPOPHMaPet_4h0'
#url='https://www.wantgoo.com/stock'
url='https://www.momoshop.com.tw/main/Main.jsp'
r = requests.get(url)
response = r.text

response
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
import requests
#加上user-agent就可以正常爬到momo站資料
headers = {'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 '}
r = requests.get(url,headers=headers)
response = r.text

response
# Out:
# '\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n \n\n\n<!DOCTYPE HTML>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="zh">\n<head>\n<link rel="shortcut icon" href="/main/favicon.ico"/>\n<link rel="Bookmark" href="/main/favicon.ico"/>\n<link rel="icon" href="/main/favicon.ico" type="image/ico"/>\n<link rel="search" href="/search/openSearch.xml" type="application/opensearchdescription+xml" title="momo購物網"/>\n\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.momoshop.com.tw">\n\n\n<title>momo&#36092;&#29289;&#32178;</title>\n\n<meta http-equiv="Content-Type" content="text/html; charset=big5">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<META NAME="Title" CONTENT="momo&#36092;&#29289;&#32178;">\n<META NAME="Author" CONTENT="momo購物網">\n<META NAME="Subject" CONTENT="momoshop,momo購物網">\n<META NAME="Description" CONTENT="momo&#36092;&#29289;&#32178;&#25552;&#
# ...

# %%
headers = {
'authority':'www.momoshop.com.tw',
'method':'GET',
'path':'/main/Main.jsp',
'scheme':'https',
'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'accept-encoding':'gzip, deflate, br',
'accept-language':'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
'cache-control':'max-age=0',
'cookie':'CAD=1; NSC_MC-xxx.npnptipq.dpn.ux*80=ffffffff0934540745525d5f4f58455e445a4a4229a0; __cfduid=d1dc489787526a161b29f587b16d27a291585385437; bid=b00eb42393434ff017dda481101b915d; isBI=1; ARK_ID=JS09f2b0cc56802e7f3ed8526fa72d85f009f2; _atrk_siteuid=6leu7eUX4uJEe_AH; __auc=81882ce917120560162d666aaf9; _mwa_uniCampaignInfo=1585385440667243886.1585385440667; __BWfp=c1585385440922x8882b9900; _ga=GA1.3.1744659791.1585385441; _fbp=fb.3.1585385439437.1603845504; _gcl_au=1.1.2127869419.1585385442; _TUCU=googleshop; _bworgid=CDA20200326161450453250; _tam=F_jdNEcAJsfySXvvVwG2v87g; CN=undefined; CM=undefined; l_code=1202900000; FTOOTH=12; DCODE=1202900014; isTN1=1; couponNumber=28; WishListNumber=0; notReadNumber=0; customer=1; st=d95be7b446a3870283d33ee2216c4f81; _wau=201603426598.34.1; ck_mlu="RjEyNjc1MjUzMg=="; _atrk_uid=a1387d0e9762bf2115a883c1dc6b415dc70d3ec3b8bfa21a5cf1dd0c8e5df16b; NSC_MC_TTP_WT=ffffffffc3a02ac945525d5f4f58455e445a4a4229a0; TN=H6SJ1FK5W8B11J01707Z; _gac_UA-22652017-1=1.1585670721.Cj0KCQjw1Iv0BRDaARIsAGTWD1uPzwupXsjAQjEazX4P2GkbIjovWch3zPrOIYbz701sZuRkzarLwzIaAhklEALw_wcB; _gac_=1.1585670722.Cj0KCQjw1Iv0BRDaARIsAGTWD1uPzwupXsjAQjEazX4P2GkbIjovWch3zPrOIYbz701sZuRkzarLwzIaAhklEALw_wcB; _gcl_aw=GCL.1585670722.Cj0KCQjw1Iv0BRDaARIsAGTWD1uPzwupXsjAQjEazX4P2GkbIjovWch3zPrOIYbz701sZuRkzarLwzIaAhklEALw_wcB; GoodsBrowsingHistory="2516304_1577284731,6627793_1578565616,6581844_1577284727,6581840_1577284728"; _gcl_marco=1.513181728.1585671383; JSESSIONID=83BF4A52FE6BA053F58B358175BD388D-m1.shop22; __asc=93d0674917174748e95f36995a3; _gid=GA1.3.1277994847.1586796728; _mwa_uniVisitorInfo=1585385440665834489.1585385440665.3.1586796728042; _atrk_ssid=L9KS_h3NGUlgB1HPd2DUbd; appier_page_isView_ERlDyPL9yO7gfOb=f42a524e779bd74dc4d8c3f4c7cf713fea37ab2fbf23e346b8d74d9359dc7aea; _TUCS=1; _TUCI_T=sessionNumber+18365&pageView+18365&productPageView+18352; Tagtoo_pta=pta_03+_&gpa+_&gpb+_&gpc+_1039_&vip+_; appier_utmz=%7B%22csr%22%3A%22www.momoshop.com.tw%22%2C%22timestamp%22%3A1586796730%2C%22lcsr%22%3A%22www.momoshop.com.tw%22%7D; _atrk_sessidx=4; appier_pv_counterERlDyPL9yO7gfOb=1; _mwa_uniSessionInfo=1586796728041552100.1586796728041.4.1586796780202; _TUCI=sessionNumber+1073&ECId+1039&hostname+www.momoshop.com.tw&pageView+3264&productPageView+5996&Member',
'referer':'https://www.momoshop.com.tw/',
'sec-fetch-dest':'document',
'sec-fetch-mode':'navigate',
'sec-fetch-site':'same-origin',
'sec-fetch-user':'?1',
'upgrade-insecure-requests':'1',
'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
}
r = requests.get(url,headers=headers)
response = r.text

response
# Out:
# '\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n \n\n\n<!DOCTYPE HTML>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="zh">\n<head>\n<link rel="shortcut icon" href="/main/favicon.ico"/>\n<link rel="Bookmark" href="/main/favicon.ico"/>\n<link rel="icon" href="/main/favicon.ico" type="image/ico"/>\n<link rel="search" href="/search/openSearch.xml" type="application/opensearchdescription+xml" title="momo購物網"/>\n\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.momoshop.com.tw">\n\n\n<title>momo&#36092;&#29289;&#32178;</title>\n\n<meta http-equiv="Content-Type" content="text/html; charset=big5">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<META NAME="Title" CONTENT="momo&#36092;&#29289;&#32178;">\n<META NAME="Author" CONTENT="momo購物網">\n<META NAME="Subject" CONTENT="momoshop,momo購物網">\n<META NAME="Description" CONTENT="momo&#36092;&#29289;&#32178;&#25552;&#
# ...
