# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})
#print(movie_item)
for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 我的失蹤爸爸, ID: 10546
# Movie: 不愛鋼琴師, ID: 10542
# Movie: 神之一手：鬼手篇, ID: 10520
# Movie: 囚愛之家, ID: 10515
# Movie: A+瞎妹, ID: 10508
# Movie: 搖滾師匠：細野晴臣, ID: 10502
# Movie: 最後晚安曲, ID: 10499
# Movie: 我出去醫下, ID: 10494
# Movie: 依然相信, ID: 10487
# Movie: 電影版 地獄少女, ID: 10525
# Movie: 刺激1995, ID: 10518
# Movie: 通靈少年2020, ID: 10517
# Movie: 安雅的回家路, ID: 10516
# Movie: 牆內的房客, ID: 10512
# Movie: 南山的部長們, ID: 10509
# Movie: 另類神父, ID: 10500
# Movie: 破．局, ID: 10496
# Movie: 劇場版 不起眼女主角培育法 Fine, ID: 10486
# Movie: 複製柔伊, ID: 10455
# Movie: 練愛iNG, ID: 10442
# Movie: 鋼鐵勳章, ID: 10432
# Movie: 我，最親愛的, ID: 10503
# Movie: 血衛, ID: 10469
# Movie: 導演先生的完美假期, ID: 10545
# Movie: 狂飆一夢, ID: 10506
# Movie: 親愛的莎瑪, ID: 10491
# Movie: 大畫特務, ID: 10478
# Movie: 戰慄糖果屋, ID: 10472
# Movie: 明明會說話, ID: 10440
# Movie: 艾瑪, ID: 10396
# Movie: 千日千夜, ID: 10490
# Movie: 鳴鳥不飛：烏雲密布, ID: 10458
# Movie: 哥布林殺手 劇場版, ID: 10438
# Movie: 女鬼橋, ID: 10437
# Movie: 怨咒, ID: 10421
# Movie: 極地守護犬, ID: 10383
# Movie: 叔．叔, ID: 10371
# Movie: 隱形人, ID: 10359
# Movie: 電影音效傳奇：好萊塢之聲, ID: 10484
# Movie: 悲慘世界, ID: 10479
# Movie: 陰櫥, ID: 10457
# Movie: 絕命大平台, ID: 10447
# Movie: 李察朱威爾事件, ID: 10368
# Movie: 音速小子, ID: 9246
# Movie: 雨天．紐約, ID: 10476
# Movie: 超＂人＂氣動物園, ID: 10445
# Movie: 全境失控, ID: 10426
# Movie: 我的寶貝男孩, ID: 10489
# Movie: 猛禽小隊：小丑女大解放, ID: 10268
# Movie: 王牌辯士, ID: 10346
# Movie: 紅鞋公主與七矮人, ID: 10417
# Movie: 1917, ID: 10189
# Movie: 她們, ID: 10202
# Movie: 變身特務, ID: 9008
# Movie: 巧虎電影：英雄遊樂園, ID: 10429
# Movie: 青春催落去, ID: 10404
# Movie: 星星知我心, ID: 10409
# Movie: 逃出天堂島, ID: 10384
# Movie: 別告訴她, ID: 10382
# Movie: 真愛裁會贏, ID: 10362
# Movie: 霹靂嬌娃, ID: 10124
# Movie: CATS貓, ID: 10166
# Movie: 燃燒女子的畫像, ID: 10069
# Movie: STAR WARS : 天行者的崛起, ID: 10225
# Movie: 8級警戒, ID: 10323
# Movie: 去年聖誕節, ID: 10256
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 賽道狂人, ID: 10097
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 絕鯊47：猛鯊出籠, ID: 10214
# Movie: 貓咪知道但是貓咪不說, ID: 10203
# Movie: 寄生上流, ID: 10020
# Movie: 失控危城, ID: 9710
# Movie: 假面飯店, ID: 9641
# Movie: 潛艦獵殺令, ID: 8828
# Movie: 在咖啡冷掉之前, ID: 8730
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10437

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 苗栗, 代號(area_id): 15
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})
#print(movie_date)
# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 三月 25
# 三月 26
# 三月 27
# 三月 28
# 三月 29

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-03-25"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# Out:
# <div class="pc-movie-schedule-form">
#     <div class="area_timebox">
#    <div class="area_title">台北市</div>
#       <ul id="theater_id_32" class="area_time _c jq_area_time" data-theater_name="台北美麗華大直影城" data-theater_url="http://www.miramarcinemas.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=32" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=32">台北美麗華大直影城</a>
#            <span>02-85022208</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73368124" class="gabtn"
#                         value="2020-03-25 13:00:00"  data-movie="2cdf6afe716d47fe94a945187eba5f16"
#                         data-cinema="40288eb0050f31210ada0f55676b1bbc" data-session="602c4658a19847abb161551929e44a76"
#                         data-date="1585065600" data-time="1585112400"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="13:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73368124" class="select">13:00</label>
#                                                                                     <input type="radio" name="schedule_list" id="73368125" class="gabtn"
#                         value="2020-03-25 16:00:00"  data-movie="2cdf6afe716d47fe94a945187eba5f16"
#                         data-cinema="40288eb0050f31210ada0f55676b1bbc" data-session="dde730173aac464482675736fc33e1f6"
#                         data-date="1585065600" data-time="1585123200"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="16:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73368125" class="select">16:00</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_39" class="area_time _c jq_area_time" data-theater_name="台北日新威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=39" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=39">台北日新威秀影城</a>
#            <span>02-23315256</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73385691" class="gabtn"
#                         value="2020-03-25 22:10:00"  data-movie="84b823bc40e1473d88bd934ee43e66dc"
#                         data-cinema="40288eb0050f542401050f551a8a48c3" data-session="314f11109d3b4c49ab2d4f146d821715"
#                         data-date="1585065600" data-time="1585145400"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="22:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73385691" class="select">22:10</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_42" class="area_time _c jq_area_time" data-theater_name="喜滿客絕色影城" data-theater_url="http://www.cinema7.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=42" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=42">喜滿客絕色影城</a>
#            <span>02-23811339</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73388514" class="gabtn"
#                         value="2020-03-25 15:10:00"  data-movie="7a877af2dd2540c3b107acf353205c0b"
#                         data-cinema="40288eb0050f542401050f55532606b5" data-session="862430000d2242e481633ec8efe73a1b"
#                         data-date="1585065600" data-time="1585120200"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="15:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73388514" class="select">15:10</label>
#                                                                                     <input type="radio" name="schedule_list" id="73388515" class="gabtn"
#                         value="2020-03-25 19:10:00"  data-movie="7a877af2dd2540c3b107acf353205c0b"
#                         data-cinema="40288eb0050f542401050f55532606b5" data-session="6e95cfa16ba946ee82b3f50e17a4a265"
#                         data-date="1585065600" data-time="1585134600"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="19:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73388515" class="select">19:10</label>
#                                                                                     <input type="radio" name="schedule_list" id="73388516" class="gabtn"
#                         value="2020-03-25 20:55:00"  data-movie="7a877af2dd2540c3b107acf353205c0b"
#                         data-cinema="40288eb0050f542401050f55532606b5" data-session="d1238ec0b392459a88dd9f9d698619da"
#                         data-date="1585065600" data-time="1585140900"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="20:55"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73388516" class="select">20:55</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_45" class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
#            <span>02-87805566</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73366993" class="gabtn"
#                         value="2020-03-25 14:15:00"  data-movie="6309f040ea034239b2ce8847ff9ae47f"
#                         data-cinema="40288eb0050f542401050f554e7e0674" data-session="c8138c0a673a4989912c0693368738ce"
#                         data-date="1585065600" data-time="1585116900"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="14:15"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73366993" class="select">14:15</label>
#                                                                                     <input type="radio" name="schedule_list" id="73366994" class="gabtn"
#                         value="2020-03-25 17:15:00"  data-movie="6309f040ea034239b2ce8847ff9ae47f"
#                         data-cinema="40288eb0050f542401050f554e7e0674" data-session="a1ffc7f383b342e2a444eea9865cb6ea"
#                         data-date="1585065600" data-time="1585127700"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="17:15"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73366994" class="select">17:15</label>
#                                                                                     <input type="radio" name="schedule_list" id="73366995" class="gabtn"
#                         value="2020-03-25 19:30:00"  data-movie="6309f040ea034239b2ce8847ff9ae47f"
#                         data-cinema="40288eb0050f542401050f554e7e0674" data-session="538f9bf20817432cbf66f32423c762bf"
#                         data-date="1585065600" data-time="1585135800"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="19:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73366995" class="select">19:30</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_118" class="area_time _c jq_area_time" data-theater_name="京站威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=118" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=118">京站威秀影城</a>
#            <span>02-25525511</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73359550" class="gabtn"
#                         value="2020-03-25 13:35:00"  data-movie="74a0e186850d437ea706570d5fc6c3ef"
#                         data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-session="faa709a6bc7f477bb87ee08e806c7645"
#                         data-date="1585065600" data-time="1585114500"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="13:35"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73359550" class="select">13:35</label>
#                                                                                     <input type="radio" name="schedule_list" id="73359551" class="gabtn"
#                         value="2020-03-25 17:05:00"  data-movie="74a0e186850d437ea706570d5fc6c3ef"
#                         data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-session="efe29bc7326646d0ad07dd34f4e7339c"
#                         data-date="1585065600" data-time="1585127100"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="17:05"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73359551" class="select">17:05</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_186" class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_url="http://www.centuryasia.com.tw/default.aspx" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
#            <span>02-27888185</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                 <span class="tapB">中文</span>            </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73381194" class="gabtn"
#                         value="2020-03-25 11:10:00"  data-movie="e50806ef688f415aabc4e29338fd81cc"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="b5f7b9efe9464df5a9d291ee4bf5d914"
#                         data-date="1585065600" data-time="1585105800"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="11:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73381194" class="select">11:10</label>
#                                                                                     <input type="radio" name="schedule_list" id="73381195" class="gabtn"
#                         value="2020-03-25 13:00:00"  data-movie="e50806ef688f415aabc4e29338fd81cc"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="c3f1204fd1f148bd9d8b8c322e945093"
#                         data-date="1585065600" data-time="1585112400"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="13:00"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73381195" class="select">13:00</label>
#                                                                                     <input type="radio" name="schedule_list" id="73381196" class="gabtn"
#                         value="2020-03-25 14:50:00"  data-movie="e50806ef688f415aabc4e29338fd81cc"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="5712d297b8664f92b15bac58905da2cb"
#                         data-date="1585065600" data-time="1585119000"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="14:50"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73381196" class="select">14:50</label>
#                                                                                     <input type="radio" name="schedule_list" id="73381197" class="gabtn"
#                         value="2020-03-25 16:40:00"  data-movie="e50806ef688f415aabc4e29338fd81cc"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="66f3cdd618b44473b69d8dc3bdd2d96e"
#                         data-date="1585065600" data-time="1585125600"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="16:40"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73381197" class="select">16:40</label>
#                                                                                     <input type="radio" name="schedule_list" id="73381198" class="gabtn"
#                         value="2020-03-25 18:30:00"  data-movie="e50806ef688f415aabc4e29338fd81cc"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="2fd2f331b10b46898619a76a27bff921"
#                         data-date="1585065600" data-time="1585132200"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="18:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73381198" class="select">18:30</label>
#                                                                                     <input type="radio" name="schedule_list" id="73381199" class="gabtn"
#                         value="2020-03-25 20:20:00"  data-movie="e50806ef688f415aabc4e29338fd81cc"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="0bace4c7b9724633b020bd5ba89525cd"
#                         data-date="1585065600" data-time="1585138800"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="20:20"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73381199" class="select">20:20</label>
#                                                                                     <input type="radio" name="schedule_list" id="73381200" class="gabtn"
#                         value="2020-03-25 22:10:00"  data-movie="e50806ef688f415aabc4e29338fd81cc"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="411cbe7d6a7746e2a39453c6b3411d81"
#                         data-date="1585065600" data-time="1585145400"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="22:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73381200" class="select">22:10</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_254" class="area_time _c jq_area_time" data-theater_name="MUVIE CINEMAS台北松仁威秀" data-theater_url="https://www.vscinemas.com.tw/vsweb/theater/detail2.aspx?id=23" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=254" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=254">MUVIE CINEMAS台北松仁威秀</a>
#            <span>(02)8780-0800</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="73385316" class="gabtn"
#                         value="2020-03-25 20:35:00"  data-movie="d5d6d111d52d4e0881c4502944065da9"
#                         data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-session="03b968f8918d475f8d5552a0bcc72942"
#                         data-date="1585065600" data-time="1585139700"
#                         data-movie_type="數位"
#                         data-movie_title="女鬼橋"
#                         data-movie_date="03.25"
#                         data-movie_time="20:35"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '女鬼橋']" data-ezding="ezding"
#                         />
#                     <label for="73385316" class="select">20:35</label>
#                                                </div>
#            </li>
#           </ul>
#    </div>
#
#     <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop"></div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#         <form method="get" action="https://movies.yahoo.com.tw/ticket/ezding_ticket" target="_blank" id="form_schedule">
#                 <div class="ezding_ticket_value">
#             <input type="hidden" name="movie_id" value="">
#             <input type="hidden" name="cinema_id" value="">
#             <input type="hidden" name="session_id" value="">
#             <input type="hidden" name="date" value="">
#             <input type="hidden" name="time" value="">
#             <input type="hidden" name="campaign_code" value="yahoopc">
#         </div>
#         <ul class="top_infos">
#             <li>
#                 <p>片名</p>
#                 <h3 id="top_infos_movie"></h3>
#             </li>
#             <li>
#                 <p>影城</p>
#                 <h3 id="top_infos_theater"></h3>
#             </li>
#             <li>
#                 <p>日期</p>
#                 <h3 id="top_infos_date"></h3>
#             </li>
#             <li>
#                 <p>版本</p>
#                 <h3 id="top_infos_movie_type"></h3>
#             </li>
#             <li>
#                 <p>時間</p>
#                 <h3 id="top_infos_time"></h3>
#             </li>
#         </ul>
#
#         <div class="booking_seats">
#             <a href="#" class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']">全部電影場次</a>
#             <a href="#" class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" target="_blank">官網訂票</a>
#             <p id="no_theater_url" class="no_theater_url">無提供官網訂票</p>
#
#             <p id="booking_number" class="booking_number">人數</p>
#             <div class="booking_seat_group jq_booking_seat_group">
#                                     <input type="radio" name="tickets" id="seat_1" value="1" />
#                     <label for="seat_1">1</label>
#                                     <input type="radio" name="tickets" id="seat_2" value="2"  checked />
#                     <label for="seat_2">2</label>
#                                     <input type="radio" name="tickets" id="seat_3" value="3" />
#                     <label for="seat_3">3</label>
#                                     <input type="radio" name="tickets" id="seat_4" value="4" />
#                     <label for="seat_4">4</label>
#                                     <input type="radio" name="tickets" id="seat_5" value="5" />
#                     <label for="seat_5">5</label>
#                                     <input type="radio" name="tickets" id="seat_6" value="6" />
#                     <label for="seat_6">6</label>
#                             </div>
#             <button type="submit" class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']">選位</button>
#             <a href="#" class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" target="_blank">官網訂票</a>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#         </form>
#
#         <!-- 無官網訂票區塊 -->
#         <div class="no_theater_section">
#             <p>無提供官網訂票</p>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#     </div>
# </div></div>

# %%
for p in html:
    gabtn=p.find("input", attrs={"class":"gabtn"})
    theater=gabtn['data-movie_type']
    print('電影院:',p['data-theater_name'])
    print('放映類型:',gabtn['data-movie_type'])
    print('放映時間:',gabtn['value'])
    print('------------------------')
#print(html)
# Out:
# 電影院: 台北美麗華大直影城
# 放映類型: 數位
# 放映時間: 2020-03-25 13:00:00
# ------------------------
# 電影院: 台北日新威秀影城
# 放映類型: 數位
# 放映時間: 2020-03-25 22:10:00
# ------------------------
# 電影院: 喜滿客絕色影城
# 放映類型: 數位
# 放映時間: 2020-03-25 15:10:00
# ------------------------
# 電影院: 台北信義威秀影城
# 放映類型: 數位
# 放映時間: 2020-03-25 14:15:00
# ------------------------
# 電影院: 京站威秀影城
# 放映類型: 數位
# 放映時間: 2020-03-25 13:35:00
# ------------------------
# 電影院: 喜樂時代影城南港店
# 放映類型: 數位
# 放映時間: 2020-03-25 11:10:00
# ------------------------
# 電影院: MUVIE CINEMAS台北松仁威秀
# 放映類型: 數位
# 放映時間: 2020-03-25 20:35:00
# ------------------------
