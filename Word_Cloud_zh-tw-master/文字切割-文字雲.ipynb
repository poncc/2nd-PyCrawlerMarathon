# %%
# coding: utf-8
# 部分參考: https://ithelp.ithome.com.tw/articles/10192043 
#       非常感謝王選仲大大
# 部分參考 http://blog.fukuball.com/ru-he-shi-yong-jieba-jie-ba-zhong-wen-fen-ci-cheng-shi/
#       非禪感謝林志傑 Fukuball大大
# 字典來自 https://git.oschina.net/fxsjy/jieba
#       真的是做最好的中文分词组件
#

from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
import jieba
import numpy as np
from collections import Counter

#要分析的來源，這個範例是五月天20首歌
text_from_file_with_apath = open(r'lyrics.txt', "r",encoding="utf-8").read()

#設定字典
jieba.set_dictionary('dict.big.txt')
#設定自訂的字典，譬如五月天的 "動次"
jieba.load_userdict(r'userdict_mayday.txt')

#設定停用詞，譬如唱歌會用到的oh，喔
with open(r'stopWord_mayday.txt', 'r', encoding='utf8') as f:  
    stops = f.read().split('\n') 

#
#開始段詞與排序，沒錯就這麼簡單就做完了
#
terms = [t for t in jieba.cut(text_from_file_with_apath, cut_all=True) if t not in stops]
sorted(Counter(terms).items(), key=lambda x:x[1], reverse=True) 

print(terms)
#中文繪圖需要中文字體，請自己從windows font目錄抓
#微軟正黑體
font = r'msjh.ttc'
#想要文字雲出現的圖示
#mask = np.array(Image.open(r"../wordcloudImg/star.png"))
x, y = np.ogrid[:300, :300]
mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)

#背景顏色預設黑色，改為白色
#mark改用五月天的皇冠
#其他參數請自行參考wordcloud
my_wordcloud = WordCloud(background_color="white",mask=mask,font_path=font,collocations=False, width=2400, height=2400, margin=2)  
my_wordcloud.generate_from_frequencies(frequencies=Counter(terms))

#產生圖片
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(my_wordcloud,interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
#顯示用
plt.show()

#存檔用
#plt.savefig("Mayday_Wordcloud.png")
# Out:
# Building prefix dict from /Users/poncc/Documents/GitHub/2nd-PyCrawlerMarathon/Word_Cloud_zh-tw-master/dict.big.txt ...
# Loading model from cache /var/folders/68/t9g86v0d0ys2rpbv_g1xxrph0000gn/T/jieba.uf4a3042762982af6b1a715471bbe1462.cache
# Loading model cost 1.079 seconds.
# Prefix dict has been built successfully.
# ['說', ' ', '明知', '不在', ' ', '問', '\n', '空氣', ' ', '代替', ' ', '出聲', '\n', '習慣', ' ', '永不', '癒合', ' ', '固執', '傷痕', '\n', '思念', '撕裂', '靈魂', '\n', '\n', '相片', ' ', '讓你能', '保存', ' ', '洗', '一本', '\n', '毛衣', ' ', '準備', ' ', '一層', '\n', ' ', '孤單', '孤單時', '時刻', ' ', '安慰', '體溫', '\n', '留', '一份', '\n', '\n', '願', '一個', ' ', '一個', '人海', '浮沉', '\n', '願', '走過', ' ', '風雨', ' ', '時分', '\n', '\n', '願', '一個', ' ', '承受', '世界', '殘忍', '\n', '願', '眼淚', '陪你到', ' ', '永恆', '\n', '\n', '走', '後', ' ', '愛情', '遺', '跡', ' ', '像是', '空城', '\n', '遺落', ' ', '杯子', '手套', ' ', '笑聲', '\n', '最後', ' ', '帶走', ' ', '脆弱', '\n', '放不下', '人', '\n', '\n', '也許', '未來', ' ', '找到', ' ', '懂', '疼', ' ', '更好', '人', '\n', '下段', '旅程', ' ', '一定', '定要', ' ', '幸福', '豐盛', '\n', '\n', '願', '一個', ' ', '一個', '人海', '浮沉', '\n', '願', '走過', ' ', '風雨', ' ', '時分', '\n', '願', '一個', ' ', '承受', '世界', '殘忍', '\n', '願', '眼淚', '陪你到', ' ', '永恆', '\n', '\n', '說', ' ', '明知', '不在', ' ', '問', '\n', '只因', ' ', '習慣', '滿足', ' ', '眼神', '\n', ' ', '最後', '一個', ' ', '奢求', '\n', '只求', '快樂', '人生', '\n', '\n', '只求', '命運', ' ', '帶你去', '一段', ' ', '全新', '旅程', '\n', '幸福', '天涯', '飛奔', '\n', '回頭', '往前', '飛奔', '\n', '請', '忘', ' ', '一個', '\n', '\n', '哭', '太', '累', ' ', '傷', '太', '深', ' ', '愛', '太', '傻', '\n', '哭', ' ', '末日', ' ', '要來', ' ', 'OH', '∼', '\n', '\n', '聽', '慢', '歌', ' ', '很慢', '很慢', '歌', ' ', '聽', '心如刀割', '刀割', '\n', '是不是', '應該', ' ', '換', '一種', ' ', '節奏', ' ', 'OH', '∼', '\n', '\n', '問', '\n', ' ', '錯', ' ', '誰是誰非', ' ', '虧欠', '\n', '反正', '錯', ' ', '反正', '輸', ' ', '反正', ' ', '陪', '快樂', '\n', '\n', ' ', ' ', ' ', '\n', '心跳', ' ', '動次', '動次', ' ', '動次', '動次', ' ', '感覺', '\n', '\n', ' ', '站', '坐', ' ', '躺', '趴', ' ', '快樂', '\n', '音樂', ' ', '動次', '動次', ' ', '動次', '動次', ' ', '聾', '\n', '\n', ' ', '不想', ' ', '不等', ' ', '不快', '快樂', ' ', '傷心', '人別', '聽', '慢', '歌', '\n', '\n', '人生', '生分', '分分', '分分合合', '分合', '合合', ' ', '愛情', '拉拉', '拉拉扯扯', '拉扯', '扯扯', ' ', '一路', '曲曲', '曲曲折', '曲曲折折', '曲折', '折', '\n', '期待', ' ', '明日', ' ', '新景', '景色', ' ', 'OH', '∼', '\n', '\n', '憤青', '釋懷', ' ', '光棍', '戀愛', ' ', '悲劇', '圓滿', '\n', '一段', '爭執', ' ', '飛出', ' ', '和平', '和平鴿', ' ', 'OH', '∼', '\n', '\n', '問', '\n', ' ', '錯', ' ', '誰是誰非', ' ', '虧欠', '\n', '反正', '錯', ' ', '反正', '輸', ' ', '反正', ' ', '陪', '快樂', '\n', '\n', ' ', ' ', ' ', '\n', '心跳', ' ', '動次', '動次', ' ', '動次', '動次', ' ', '感覺', '\n', '\n', ' ', '站', '坐', ' ', '躺', '趴', ' ', '快樂', '\n', '音樂', ' ', '動次', '動次', ' ', '動次', '動次', ' ', '聾', '\n', '\n', '\n', ' ', '不想', ' ', '不等', ' ', '不快', '快樂', ' ', '傷心', '人別', '聽', '慢', '歌', '\n', '\n', '\n', ' ', ' ', ' ', '\n', '心跳', ' ', '動次', '動次', ' ', '動次', '動次', ' ', '感覺', '\n', '\n', ' ', '站', '坐', ' ', '躺', '趴', ' ', '快樂', '\n', '音樂', ' ', '動次', '動次', ' ', '動次', '動次', ' ', '聾', '\n', '\n', ' ', '不想', ' ', '不等', ' ', '此時', '此刻', ' ', ' ', '貫徹', '快樂', '\n', ' ', '不想', ' ', '不等', ' ', '不快', '快樂', ' ', '傷心', '人別', '聽', '慢', '歌', '\n', '\n', '空無一人', '大街', ' ', '闖入', '無人', '婚紗', '婚紗店', ' ', '妳', '披上', '雪白', '誓言', '\n', '世界', '已', '灰飛煙滅', ' ', '愛', '矗立', '高樓', '間', ' ', '真的', ' ', ' ', '幻覺', '\n', '\n', '時光', '遺忘', '背面', ' ', '獨坐', '殘破', '台', '階', ' ', '亂世', '離別', '\n', '天空', '中間', ' ', '剩', '傾盆', '思念', ' ', '相識', ' ', '相戀', ' ', '是不是', '擦肩', '\n', '\n', '失去', '風景', '面', ' ', '佔據', '一條', '一條街', ' ', '一步', '一步步', '步步', '曾經', ' ', '一步', '一步步', '步步', '想念', ' ', '腳下', '蔓延', '\n', '充滿', '回憶', '面', ' ', '自流', '流浪', '海角', '天邊', ' ', '一步', '一步步', '步步', '走過', ' ', '當時', '心願', '\n', '\n', '格林', '格林威治', '大鐘', '前', ' ', '歸零', '超載', '傷悲', ' ', '揹', '諾言', '\n', '一起', '起計', '畫', '路線', ' ', '對照', '孤單', '旅店', ' ', '一聲', '晚安', ' ', '喚醒', ' ', '淚腺', '\n', '\n', '時代', '時代廣場', '廣場', '跨', '年', ' ', '頤和', '花季', '藍天', ' ', '數', '願望', '指尖', '\n', '當時', '心願', ' ', '殘缺', ' ', '後悔', ' ', '後退', ' ', '是不是', '只能', '往前', '\n', '\n', '失去', '風景', '面', ' ', '佔據', '一條', '一條街', ' ', '一步', '一步步', '步步', '曾經', ' ', '一步', '一步步', '步步', '想念', ' ', '腳下', '蔓延', '\n', '充滿', '回憶', '面', ' ', '自流', '流浪', '海角', '天邊', ' ', '一步', '一步步', '步步', '走過', ' ', '當時', '心願', '\n', '\n', '生如', '浮萍', '般', '卑微', ' ' ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-b58dbb43de0e> in <module>
#      47 #其他參數請自行參考wordcloud
#      48 my_wordcloud = WordCloud(background_color="white",mask=mask,font_path=font,collocations=False, width=2400, height=2400, margin=2)
# ---> 49 my_wordcloud.generate_from_frequencies(frequencies=Counter(terms))
#      50
#      51 #產生圖片
#
# ~/opt/anaconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     432             else:
#     433                 self.generate_from_frequencies(dict(frequencies[:2]),
# --> 434                                                max_font_size=self.height)
#     435                 # find font sizes
#     436                 sizes = [x[1] for x in self.layout_]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     481             while True:
#     482                 # try to find a position
# --> 483                 font = ImageFont.truetype(self.font_path, font_size)
#     484                 # transpose font optionally
#     485                 transposed_font = ImageFont.TransposedFont(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     640
#     641     try:
# --> 642         return freetype(font)
#     643     except OSError:
#     644         if not isPath(font):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/ImageFont.py in freetype(font)
#     637
#     638     def freetype(font):
# --> 639         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     640
#     641     try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     186                     return
#     187             self.font = core.getfont(
# --> 188                 font, size, index, encoding, layout_engine=layout_engine
#     189             )
#     190         else:
#
# OSError: cannot open resource
